# %% [markdown]
# # <b><u> Project Title : Sales Prediction : Predicting sales of a major store chain Rossmann</u></b>

# %% [markdown]
#   ## <b> Problem Description </b>
#
# ### Rossmann operates over 3,000 drug stores in 7 European countries. Currently, Rossmann store managers are tasked with predicting their daily sales for up to six weeks in advance. Store sales are influenced by many factors, including promotions, competition, school and state holidays, seasonality, and locality. With thousands of individual managers predicting sales based on their unique circumstances, the accuracy of results can be quite varied.
#
# ### You are provided with historical sales data for 1,115 Rossmann stores. The task is to forecast the "Sales" column for the test set. Note that some stores in the dataset were temporarily closed for refurbishment.

# %% [markdown]
# ## <b> Data Description </b>
#
# ### <b>Rossmann Stores Data.csv </b> - historical data including Sales
# ### <b>store.csv </b> - supplemental information about the stores
#
#
# ### <b><u>Data fields</u></b>
# ### Most of the fields are self-explanatory. The following are descriptions for those that aren't.
#
# * #### Id - an Id that represents a (Store, Date) duple within the test set
# * #### Store - a unique Id for each store
# * #### Sales - the turnover for any given day (this is what you are predicting)
# * #### Customers - the number of customers on a given day
# * #### Open - an indicator for whether the store was open: 0 = closed, 1 = open
# * #### StateHoliday - indicates a state holiday. Normally all stores, with few exceptions, are closed on state holidays. Note that all schools are closed on public holidays and weekends. a = public holiday, b = Easter holiday, c = Christmas, 0 = None
# * #### SchoolHoliday - indicates if the (Store, Date) was affected by the closure of public schools
# * #### StoreType - differentiates between 4 different store models: a, b, c, d
# * #### Assortment - describes an assortment level: a = basic, b = extra, c = extended
# * #### CompetitionDistance - distance in meters to the nearest competitor store
# * #### CompetitionOpenSince[Month/Year] - gives the approximate year and month of the time the nearest competitor was opened
# * #### Promo - indicates whether a store is running a promo on that day
# * #### Promo2 - Promo2 is a continuing and consecutive promotion for some stores: 0 = store is not participating, 1 = store is participating
# * #### Promo2Since[Year/Week] - describes the year and calendar week when the store started participating in Promo2
# * #### PromoInterval - describes the consecutive intervals Promo2 is started, naming the months the promotion is started anew. E.g. "Feb,May,Aug,Nov" means each round starts in February, May, August, November of any given year for that store

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as  sns 
plt.rcParams['figure.figsize']=(10,6)
pd.set_option('display.max_columns',30)
plt.rcParams['agg.path.chunksize'] = 10000

# %% [markdown]
# # **Let's import our data first and get to know about our data:**

# %%
#rossmann data: includes historical data
rossmann=pd.read_csv(r'E:\databsae\rossmann\rossmann_store.csv')
store=pd.read_csv(r'E:\databsae\rossmann\store.csv')
# Out:
# C:\Users\ajay\AppData\Local\Temp\ipykernel_5684\3951434220.py:2: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   rossmann=pd.read_csv(r'E:\databsae\rossmann\rossmann_store.csv')

# %%
#head of the rossmann data
rossmann.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
#shape of rossmann data
rossmann.shape
# Out:
# (1017209, 9)

# %%
# head of store data
store.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# 2  Jan,Apr,Jul,Oct
# 3              NaN
# 4              NaN

# %%
# shape of store data
store.shape
# Out:
# (1115, 10)

# %%
#description of  rossmann data
rossmann.describe(percentiles=[0.25,.50,.75,0.90])
# Out:
#               Store     DayOfWeek         Sales     Customers          Open  \
# count  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06
# mean   5.584297e+02  3.998341e+00  5.773819e+03  6.331459e+02  8.301067e-01
# std    3.219087e+02  1.997391e+00  3.849926e+03  4.644117e+02  3.755392e-01
# min    1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.800000e+02  2.000000e+00  3.727000e+03  4.050000e+02  1.000000e+00
# 50%    5.580000e+02  4.000000e+00  5.744000e+03  6.090000e+02  1.000000e+00
# 75%    8.380000e+02  6.000000e+00  7.856000e+03  8.370000e+02  1.000000e+00
# 90%    1.004000e+03  7.000000e+00  1.028800e+04  1.116000e+03  1.000000e+00
# max    1.115000e+03  7.000000e+00  4.155100e+04  7.388000e+03  1.000000e+00
#
#               Promo  SchoolHoliday
# count  1.017209e+06   1.017209e+06
# mean   3.815145e-01   1.786467e-01
# std    4.857586e-01   3.830564e-01
# min    0.000000e+00   0.000000e+00
# 25%    0.000000e+00   0.000000e+00
# 50%    0.000000e+00   0.000000e+00
# 75%    1.000000e+00   0.000000e+00
# 90%    1.000000e+00   1.000000e+00
# max    1.000000e+00   1.000000e+00

# %%
#info of data 
rossmann.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Store          1017209 non-null  int64
#  1   DayOfWeek      1017209 non-null  int64
#  2   Date           1017209 non-null  object
#  3   Sales          1017209 non-null  int64
#  4   Customers      1017209 non-null  int64
#  5   Open           1017209 non-null  int64
#  6   Promo          1017209 non-null  int64
#  7   StateHoliday   1017209 non-null  object
#  8   SchoolHoliday  1017209 non-null  int64
# dtypes: int64(7), object(2)
# memory usage: 69.8+ MB

# %%
# no. of stores we have
rossmann.Store.nunique()
# Out:
# 1115

# %%
#highest sales 
rossmann.Sales.max()
# Out:
# 41551

# %%
#description of store data
store.describe()
# Out:
#             Store  CompetitionDistance  CompetitionOpenSinceMonth  \
# count  1115.00000          1112.000000                 761.000000
# mean    558.00000          5404.901079                   7.224704
# std     322.01708          7663.174720                   3.212348
# min       1.00000            20.000000                   1.000000
# 25%     279.50000           717.500000                   4.000000
# 50%     558.00000          2325.000000                   8.000000
# 75%     836.50000          6882.500000                  10.000000
# max    1115.00000         75860.000000                  12.000000
#
#        CompetitionOpenSinceYear       Promo2  Promo2SinceWeek  Promo2SinceYear
# count                761.000000  1115.000000       571.000000       571.000000
# mean                2008.668857     0.512108        23.595447      2011.763573
# std                    6.195983     0.500078        14.141984         1.674935
# min                 1900.000000     0.000000         1.000000      2009.000000
# 25%                 2006.000000     0.000000        13.000000      2011.000000
# 50%                 2010.000000     1.000000        22.000000      2012.000000
# 75%                 2013.000000     1.000000        37.000000      2013.000000
# max                 2015.000000     1.000000        50.000000      2015.000000

# %% [markdown]
# *we can get some statistical information from here this :*

# %%
#maximim competetor distance :you can see this in upward frame
store.CompetitionDistance.max()
# Out:
# 75860.0

# %%
# average year  from which stores have competiton 
2006
# Out:
# 2006

# %%
#info of data
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      1115 non-null   int64
#  1   StoreType                  1115 non-null   object
#  2   Assortment                 1115 non-null   object
#  3   CompetitionDistance        1112 non-null   float64
#  4   CompetitionOpenSinceMonth  761 non-null    float64
#  5   CompetitionOpenSinceYear   761 non-null    float64
#  6   Promo2                     1115 non-null   int64
#  7   Promo2SinceWeek            571 non-null    float64
#  8   Promo2SinceYear            571 non-null    float64
#  9   PromoInterval              571 non-null    object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 87.2+ KB

# %% [markdown]
# # Data wrangling  and Feature Engineering:
# ***getting data ready for further process:***

# %%
#data info
rossmann.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Store          1017209 non-null  int64
#  1   DayOfWeek      1017209 non-null  int64
#  2   Date           1017209 non-null  object
#  3   Sales          1017209 non-null  int64
#  4   Customers      1017209 non-null  int64
#  5   Open           1017209 non-null  int64
#  6   Promo          1017209 non-null  int64
#  7   StateHoliday   1017209 non-null  object
#  8   SchoolHoliday  1017209 non-null  int64
# dtypes: int64(7), object(2)
# memory usage: 69.8+ MB

# %% [markdown]
#   **date** column's dtype is object we need to change it and **StateHoliday** contain binary ,but dtype is object.Let's change them

# %%
#changing data type of date column from object to datetime
rossmann['Date']=pd.to_datetime(rossmann.Date)

# %%
# let's check again 
rossmann.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Store          1017209 non-null  int64
#  1   DayOfWeek      1017209 non-null  int64
#  2   Date           1017209 non-null  datetime64[ns]
#  3   Sales          1017209 non-null  int64
#  4   Customers      1017209 non-null  int64
#  5   Open           1017209 non-null  int64
#  6   Promo          1017209 non-null  int64
#  7   StateHoliday   1017209 non-null  object
#  8   SchoolHoliday  1017209 non-null  int64
# dtypes: datetime64[ns](1), int64(7), object(1)
# memory usage: 69.8+ MB

# %%
# for Rossmann data

#checking duplicates values 
rossmann[rossmann.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Store, DayOfWeek, Date, Sales, Customers, Open, Promo, StateHoliday, SchoolHoliday]
# Index: []

# %% [markdown]
# no duplicates

# %%
#checking null values
rossmann.isnull().sum()
# Out:
# Store            0
# DayOfWeek        0
# Date             0
# Sales            0
# Customers        0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %% [markdown]
# ***no null values***

# %%
#for store data 
#head of the data
store.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# 2  Jan,Apr,Jul,Oct
# 3              NaN
# 4              NaN

# %%
#checking duplicates
store[store.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Store, StoreType, Assortment, CompetitionDistance, CompetitionOpenSinceMonth, CompetitionOpenSinceYear, Promo2, Promo2SinceWeek, Promo2SinceYear, PromoInterval]
# Index: []

# %% [markdown]
# no duplicates

# %%
#info of the data
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      1115 non-null   int64
#  1   StoreType                  1115 non-null   object
#  2   Assortment                 1115 non-null   object
#  3   CompetitionDistance        1112 non-null   float64
#  4   CompetitionOpenSinceMonth  761 non-null    float64
#  5   CompetitionOpenSinceYear   761 non-null    float64
#  6   Promo2                     1115 non-null   int64
#  7   Promo2SinceWeek            571 non-null    float64
#  8   Promo2SinceYear            571 non-null    float64
#  9   PromoInterval              571 non-null    object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 87.2+ KB

# %%
#checking null values
store.isna().sum()
# Out:
# Store                          0
# StoreType                      0
# Assortment                     0
# CompetitionDistance            3
# CompetitionOpenSinceMonth    354
# CompetitionOpenSinceYear     354
# Promo2                         0
# Promo2SinceWeek              544
# Promo2SinceYear              544
# PromoInterval                544
# dtype: int64

# %% [markdown]
# null values are present let's see what we can do

# %% [markdown]
# see here we have null values in all rows and we have exact 1115 stores, if we remove them we will loose whole data.
# Let's fill the nan values with 0

# %%
#let's fill nan values with 0
store=store.fillna(0)

# %%
#let's check again
store.isna().sum()
# Out:
# Store                        0
# StoreType                    0
# Assortment                   0
# CompetitionDistance          0
# CompetitionOpenSinceMonth    0
# CompetitionOpenSinceYear     0
# Promo2                       0
# Promo2SinceWeek              0
# Promo2SinceYear              0
# PromoInterval                0
# dtype: int64

# %% [markdown]
# ***Intuition behind filling null values with zeros :*** As we saw above ,column **CompetitionOpenSinceMonth** and **CompetitionOpenSinceYear** have same amount of null values ,so there could be a posibility that these store which don't have competition open since year also don't have competition open since month,same as with other columns containing null values.

# %%
#let's hot encode these holidays into numbers
stateholi={'0':0,
          0:0,
          'a':1,
          'b':2,
           'c':3}

# %%
rossmann['StateHoliday']=rossmann['StateHoliday'].apply(lambda x:stateholi[x])

# %% [markdown]
# **2 colums in store data need hot encoding**

# %%
# store type
storetype={'a':1,'b':2,'c':3,'d':4}
store['StoreType']=store['StoreType'].apply(lambda x :storetype[x])

# %%
# for Assortment level
assortment={'a':1,'b':2,'c':3}
store['Assortment']=store['Assortment'].apply(lambda x:assortment[x])

# %% [markdown]
# # **:>  Checking outliers in our data**

# %% [markdown]
#    **Let's join our both datasets**

# %%
#join
df=pd.merge(rossmann,store,how='outer',on='Store')

# %%
# adding day,month and year columns to 'df' dataframe
df['day']=df['Date'].dt.day
df['month']=df['Date'].dt.month
df['year']=df['Date'].dt.year

# %%
# features names
x_names=set(df.describe().columns)-{'Store','Sales'}
y_names='Sales'

# %%
#checking ouliers in  our independent variables using box plot
for i,j in enumerate(x_names):
    plt.figure(figsize=(7,5))
    plt.figure(i)
    sns.boxplot(x=j,data=df)

# %% [markdown]
#         There are two variables which have outliers :
#                                                         1.Customers
#                                                         2.CompetetionDistance

# %%
#removing outliers

df=df[df['Customers']<2000]  #dataset with only customers less than 2000

df=df[df['CompetitionDistance']<20000] #dataset with only CompetetionDistance less than 20000

# %%
#creatnig boxplot
sns.boxplot(df['Sales'])
# Out:
# C:\Users\ajay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sales'>

# %% [markdown]
# *Till now all seems good,further alterations will be done as per requirement*

# %% [markdown]
# # **Explorartory data analysis
# this will include steps like getting some information about data and visualizing them

# %%
# time period of the data we have
print('The data we have is between {}  and {} '.format(min(df.Date),max(df.Date)))
# Out:
# The data we have is between 2013-01-01 00:00:00  and 2015-07-31 00:00:00

# %% [markdown]
#       approx 2.7 years

# %%
# types of state holidays
df.StateHoliday.unique()
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %% [markdown]
#     1 = public holiday, 2 = Easter holiday, 3 = Christmas, 0 = None

# %%
#let's check most no. of StateHolidays we have during these years
df[df['StateHoliday']!=0].groupby(['StateHoliday'])['StateHoliday'].count().plot(kind='bar')
plt.legend()

# %% [markdown]
#     1= public holiday, 2= Easter holiday, 3= Christmas
#
#   **So many public holidays**

# %%
df.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo  StateHoliday  \
# 0      1          5 2015-07-31   5263        555     1      1             0
# 1      1          4 2015-07-30   5020        546     1      1             0
# 2      1          3 2015-07-29   4782        523     1      1             0
# 3      1          2 2015-07-28   5011        560     1      1             0
# 4      1          1 2015-07-27   6102        612     1      1             0
#
#    SchoolHoliday  StoreType  Assortment  CompetitionDistance  \
# 0              1          3           1               1270.0
# 1              1          3           1               1270.0
# 2              1          3           1               1270.0
# 3              1          3           1               1270.0
# 4              1          3           1               1270.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0       0
# 1                        9.0                    2008.0       0
# 2                        9.0                    2008.0       0
# 3                        9.0                    2008.0       0
# 4                        9.0                    2008.0       0
#
#    Promo2SinceWeek  Promo2SinceYear PromoInterval  day  month  year
# 0              0.0              0.0             0   31      7  2015
# 1              0.0              0.0             0   30      7  2015
# 2              0.0              0.0             0   29      7  2015
# 3              0.0              0.0             0   28      7  2015
# 4              0.0              0.0             0   27      7  2015

# %%
#which year have the highest sales
sh=df.groupby(['year'])['Sales'].max().reset_index().set_index(['year'])
plt.bar(sh.index,sh.Sales,color=['purple','cyan','black'])
plt.legend(list(sh.Sales))

# %% [markdown]
#      Even we have only 7 months of data of year 2015,still highest sales !!

# %%
ys=df.groupby(['year'])['StateHoliday'].count().reset_index()
plt.bar(ys['year'],ys['StateHoliday'],color=['red','blue','green'])
plt.ylabel('<--------------no.of holidays----------->')
plt.xlabel('<-------------year--------------->')
# Out:
# Text(0.5, 0, '<-------------year--------------->')

# %% [markdown]
#       year 2015 have highest sales because it has least numbers of holidays

# %%
#no. of year we have 
df.year.unique()
# Out:
# array([2015, 2014, 2013], dtype=int64)

# %%
# sales in year 2013
df[df['year']==2013].groupby(['month']).mean()['Sales'].plot(kind='line')
plt.xlabel('<::::::::::::YEAR 2013:::::::::::>')
plt.ylabel('<::::::::::::SALES:::::::::::>')
plt.legend(['Sales'],loc=2)

# %% [markdown]
#             At the mid of the year ,sales were highest

# %%
# sales in year 2014
df[df['year']==2014].groupby(['month']).mean()['Sales'].plot(kind='line')
plt.xlabel('<::::::::::::YEAR 2014:::::::::::>')
plt.ylabel('<::::::::::::SALES:::::::::::>')
plt.legend(['Sales'],loc=2)

# %% [markdown]
#      Here , sales were highest at the end of year

# %%
# sales in year 2015
df[df['year']==2015].groupby(['month']).mean()['Sales'].plot(kind='line')
plt.xlabel('<::::::::::::YEAR 2015:::::::::::>')
plt.ylabel('<::::::::::::SALES:::::::::::>')
plt.legend(['Sales'],loc=2)

# %%
# hihghest numbers of customers in years
df.groupby('year')['Customers'].mean().plot(kind='bar',color='black')
plt.ylabel('<--------Customers....-----.')
# Out:
# Text(0, 0.5, '<--------Customers....-----.')

# %% [markdown]
#           We have only 7 month of data for year 2015

# %%
# plotting our dependent variable which is Sales
sns.distplot(df['Sales'])
# Out:
# C:\Users\ajay\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Sales', ylabel='Density'>

# %% [markdown]
#       positively skewed ,need to use tranformation techniques and need to remove 0 values from variables

# %%
#checking data
df['Sales'].min()
# Out:
# 0

# %% [markdown]
#             we can remove sales with zeros becoz there is no sales due to holiday ,there are also some example with sales 0 we will also remove them

# %%
# new dataste
df=df[df['Sales']!=0]

# %%
#check
df['Sales'].min()
# Out:
# 124

# %%
# transformation of our dependent variable
df['Sales']=np.sqrt(df['Sales'])

# %%
#let's plot
sns.distplot(df['Sales'])
# Out:
# C:\Users\ajay\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Sales', ylabel='Density'>

# %% [markdown]
#        Now it it perfectly shaped

# %% [markdown]
# # Plotting correlation between dependent and independent variable using scatter plot ;>

# %%
#plot
for i ,j in enumerate(x_names):
    plt.figure(i)
    sns.scatterplot(x=j,y='Sales',data=df)
    plt.title(df[j].corr(df['Sales']))

# %% [markdown]
# # Plotting relation between independent variable using heatmap

# %% [markdown]
# **Checking Multicolinearity**

# %%
# Let's plot
plt.figure(figsize=(16,8))
corr=df[x_names].corr()
sns.heatmap(abs(corr),annot=True,cmap='YlGnBu')
# Out:
# C:\Users\ajay\AppData\Local\Temp\ipykernel_5684\2768597832.py:3: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   corr=df[x_names].corr()
# <AxesSubplot:>

# %% [markdown]
#         we will remove those features which have high correlation with each other features  eg.
#                                                                                               1.Promo2
#                                                                                               2.CompetitionOpenSinceYear
#                                                                                               3.Promo2SinceYear
#                                                                                               4.Promo2SinceYear
#                                                                                               5.Open
#                                                                                               6.StateHoliday
#                                                                                               7.SchoolHoliday

# %%
# let's drop; these features
x_names=x_names-{'Promo2','CompetitionOpenSinceYear','Promo2SinceYear','Open'}

# %%
#let plot again
plt.figure(figsize=(16,8))
corr=df[x_names].corr()
sns.heatmap(abs(corr),annot=True,cmap='YlGnBu')
# Out:
# C:\Users\ajay\AppData\Local\Temp\ipykernel_5684\522846085.py:3: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   corr=df[x_names].corr()
# <AxesSubplot:>

# %% [markdown]
#         Good to go

# %% [markdown]
# # ***Normalizing  input data***

# %%
#library
from sklearn.preprocessing import StandardScaler

# %%
# intiate scaler for normalizing inputs
scaler=StandardScaler()
x=scaler.fit_transform(df[x_names])
# Out:
# C:\Users\ajay\AppData\Local\Temp\ipykernel_5684\3824078154.py:3: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   x=scaler.fit_transform(df[x_names])

# %%
x.shape
# Out:
# (785058, 13)

# %%
y=df['Sales']

# %% [markdown]
# **Splitting data into trainig and test**

# %%
#library
from sklearn.model_selection import train_test_split

# %%
#let's split
x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.2,random_state=1)

# %%
# shapes of data
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (628046, 13)
# (628046,)
# (157012, 13)
# (157012,)

# %% [markdown]
# #  Applying Linear Regression :

# %%
#library
from sklearn.linear_model import LinearRegression

# %%
#initiate model
model=LinearRegression().fit(x_train,y_train)

# %%
# coef's 
model.coef_
# Out:
# array([-0.40456131,  1.36827147,  2.07196392,  3.52493956, 13.35084027,
#        -0.27443975,  0.08188111,  0.65163955,  0.87186299,  1.14375232,
#         0.24295376,  2.51966475,  0.04746429])

# %%
#let's predict
y_preds=model.predict(x_test)

# %% [markdown]
# #  Regression Evaluation

# %% [markdown]
# **On test data**

# %%
#Library
# MSE  MAE RMSE
from sklearn.metrics import mean_squared_error,mean_absolute_error

MSE=mean_squared_error(y_test,y_preds)
print('MSE :',MSE)

MAE=mean_absolute_error(y_test,y_preds)
print('MAE :',MAE)

RMSE=np.sqrt(mean_squared_error(y_test,y_preds))
print('MSE :',RMSE)
# Out:
# MSE : 57.96480888763818
# MAE : 5.804022454787528
# MSE : 7.613462345584837

# %%
#Library
# R2 score
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_preds)
print('R2 on test data:',r2)
# Out:
# R2 on test data: 0.7777734644623331

# %% [markdown]
# **on train data**

# %%
#Accuracy on train data
train_preds=model.predict(x_train)
print('Accuracy on train data is :{}'.format(r2_score(y_train,train_preds)))
# Out:
# Accuracy on train data is :0.7781698133549312

# %%
#train data
MSE=mean_squared_error(y_train,train_preds)
print('MSE on train data:',MSE)

MAE=mean_absolute_error(y_train,train_preds)
print('MAE on train data:',MAE)

RMSE=np.sqrt(mean_squared_error(y_train,train_preds))
print('MSE on train data:',RMSE)
# Out:
# MSE on train data: 57.71339238793002
# MAE on train data: 5.784235154598549
# MSE on train data: 7.5969330909209685

# %% [markdown]
#  **NOT Doing well ,let's apply ENSEMBLING technique called Random Forest**

# %%
#Random Forsest
from sklearn.ensemble import RandomForestRegressor

# %%
# set params
parameters={'n_estimators':[50,75,200,300],
            'max_depth':[5,7,2,3],
           'min_samples_split':[500,250,750],
           'min_samples_leaf':[50,75,100],
           'max_features':[3,4,5,8,10],
           'max_leaf_nodes':[None,2,3,4,5],
           'max_samples':[500,700,1000,300]}

# %%
rf=RandomForestRegressor()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
#r2 score :train data 
r2_score(y_train,rf.predict(x_train))
# Out:
# 0.9960803570978113

# %%
#r2 score :testdata 
r2_score(y_test,rf.predict(x_test))
# Out:
# 0.9722945880789944

# %% [markdown]
#    **Let's generalize this model more using HYPERPARAMETER tuning**

# %%
# let's get the default params first
rf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
#make some changes
RFregressor=RandomForestRegressor(n_estimators=80,min_samples_leaf=10,min_samples_split=35,bootstrap=True,oob_score=True)

# %%
#fit again
RFregressor.fit(x_train,y_train)
# Out:
# RandomForestRegressor(min_samples_leaf=10, min_samples_split=35,
#                       n_estimators=80, oob_score=True)

# %%
#r2 score :train data 
r2_score(y_train,RFregressor.predict(x_train))
# Out:
# 0.9697583254071909

# %%
# score on OOB (validation set)
RFregressor.oob_score_
# Out:
# 0.9615107909493871

# %%
#r2 score :testdata 
r2_score(y_test,RFregressor.predict(x_test))
# Out:
# 0.9620531917406211

# %% [markdown]
#             Boom! see scores on all sets.

# %% [markdown]
# # Residual Plot

# %%
sns.distplot(y_test-RFregressor.predict(x_test))
# Out:
# C:\Users\ajay\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Sales', ylabel='Density'>

# %% [markdown]
#      Around zero!

# %% [markdown]
# # Heteroscedasticity Plot

# %%
errors=y_test-RFregressor.predict(x_test)
sns.scatterplot(y_test,errors,color='r')
# Out:
# C:\Users\ajay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sales', ylabel='Sales'>
